# %%
# Load various imports 
import pandas as pd
import os
import librosa
import librosa.display
from sklearn import preprocessing
import numpy as np
import IPython

# %%
path_train = 'data/train_labels.csv'
path_test = 'data/test_files.csv'
num_cc = 50
df = pd.read_csv(path_train)
df['filename'] = df['filename'].map(lambda x: 'data/data/%04d.wav' % x)
le = preprocessing.LabelEncoder()
df['height'] = le.fit_transform(df['height'])
le = preprocessing.LabelEncoder()
df['pasture'] = le.fit_transform(df['pasture'])
print(len(df.index))
df.head(2)
# Out:
# 1532
#              filename  pasture  height  label
# 0  data/data/0004.wav        0       1      2
# 1  data/data/0009.wav        0       1      2

# %%
IPython.display.Audio(df.loc[4]['filename'])
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
max_pad_len = 174
def extract_features(file_name):
    try:
        audio, sample_rate = librosa.load(file_name, res_type='kaiser_fast') 
        mfccs = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=num_cc)
        pad_width = max_pad_len - mfccs.shape[1]
        mfccs = np.pad(mfccs, pad_width=((0, 0), (0, pad_width)), mode='constant')
        
    except Exception as e:
        print("Error encountered while parsing file: ", file)
        return None 
     
    return mfccs

# %%
features = []
for k,row in df.iterrows():
    class_label = row["label"]
    data = extract_features(row['filename'])
    features.append([data, class_label])
df_features = pd.DataFrame(features, columns=['feature','class_label'])
print('Finished feature extraction from ', len(df_features), ' files')
df_features['pasture'] = row['pasture']
df_features['height'] = row['height']
df_features.head(2)
# Out:
# Finished feature extraction from  1532  files
#                                              feature  class_label  pasture  \
# 0  [[-431.2328, -403.76685, -400.59433, -425.5229...            2        1
# 1  [[-475.67163, -462.17108, -454.94983, -450.248...            2        1
#
#    height
# 0       1
# 1       1

# %%
from sklearn.preprocessing import LabelEncoder
from keras.utils import to_categorical

# Convert features and corresponding classification labels into numpy arrays
X = np.array(df_features.feature.tolist())
y = np.array(df_features.class_label.tolist())

# Encode the classification labels
le = LabelEncoder()
yy = to_categorical(le.fit_transform(y)) 

# split the dataset 
from sklearn.model_selection import train_test_split 

x_train, x_test, y_train, y_test = train_test_split(X, yy, test_size=0.2, random_state = 42)

# %%
np.array(df_features.pasture.tolist())
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Convolution2D, Conv2D, MaxPooling2D, GlobalAveragePooling2D
from keras.optimizers import Adam
from keras.utils import np_utils
from sklearn import metrics 

num_rows = num_cc
num_columns = 174
num_channels = 1

x_train = x_train.reshape(x_train.shape[0], num_rows, num_columns, num_channels)
x_test = x_test.reshape(x_test.shape[0], num_rows, num_columns, num_channels)

num_labels = yy.shape[1]
filter_size = 2

# Construct model 
model = Sequential()
model.add(Conv2D(filters=16, kernel_size=2, input_shape=(num_rows, num_columns, num_channels), activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=32, kernel_size=2, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=64, kernel_size=2, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=128, kernel_size=2, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))
model.add(GlobalAveragePooling2D())

model.add(Dense(num_labels, activation='softmax'))

model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

# %%
# Display model architecture summary 
model.summary()
# Calculate pre-training accuracy 
score = model.evaluate(x_test, y_test, verbose=1)
accuracy = 100*score[1]
print("Pre-training accuracy: %.4f%%" % accuracy)
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_22 (Conv2D)           (None, 49, 173, 16)       80
# _________________________________________________________________
# max_pooling2d_19 (MaxPooling (None, 24, 86, 16)        0
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 24, 86, 16)        0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 23, 85, 32)        2080
# _________________________________________________________________
# max_pooling2d_20 (MaxPooling (None, 11, 42, 32)        0
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 11, 42, 32)        0
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 10, 41, 64)        8256
# _________________________________________________________________
# max_pooling2d_21 (MaxPooling (None, 5, 20, 64)         0
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 5, 20, 64)         0
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 4, 19, 128)        32896
# _________________________________________________________________
# max_pooling2d_22 (MaxPooling (None, 2, 9, 128)         0
# _________________________________________________________________
# dropout_22 (Dropout)         (None, 2, 9, 128)         0
# _________________________________________________________________
# global_average_pooling2d_5 ( (None, 128)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 3)                 387
# =================================================================
# Total params: 43,699
# Trainable params: 43,699
# Non-trainable params: 0
# _________________________________________________________________
# 307/307 [==============================] - 0s 1ms/step
# Pre-training accuracy: 29.6417%

# %%
#https://medium.com/@mikesmales/sound-classification-using-deep-learning-8bc2aa1990b7
from keras.callbacks import ModelCheckpoint 
from datetime import datetime 

num_epochs = 72
num_batch_size = 256

checkpointer = ModelCheckpoint(filepath='saved_models/weights.best.basic_cnn.hdf5', 
                               verbose=1, save_best_only=True)
start = datetime.now()

model.fit(x_train, y_train, batch_size=num_batch_size, epochs=num_epochs, validation_data=(x_test, y_test), verbose=1)


duration = datetime.now() - start
print("Training completed in time: ", duration)
# Out:
# Train on 1225 samples, validate on 307 samples
# Epoch 1/72
# 1225/1225 [==============================] - 5s 4ms/step - loss: 2.4011 - accuracy: 0.3673 - val_loss: 1.3039 - val_accuracy: 0.5179
# Epoch 2/72
# 1225/1225 [==============================] - 4s 4ms/step - loss: 1.5476 - accuracy: 0.5453 - val_loss: 1.0287 - val_accuracy: 0.5179
# Epoch 3/72
# 1225/1225 [==============================] - 5s 4ms/step - loss: 1.0765 - accuracy: 0.4669 - val_loss: 1.0719 - val_accuracy: 0.4332
# Epoch 4/72
# 1225/1225 [==============================] - 4s 4ms/step - loss: 1.1276 - accuracy: 0.3510 - val_loss: 1.0363 - val_accuracy: 0.5603
# Epoch 5/72
# 1225/1225 [==============================] - 4s 4ms/step - loss: 1.0430 - accuracy: 0.4653 - val_loss: 1.0033 - val_accuracy: 0.5179
# Epoch 6/72
# 1225/1225 [==============================] - 5s 4ms/step - loss: 0.9954 - accuracy: 0.5461 - val_loss: 1.0038 - val_accuracy: 0.5179
# Epoch 7/72
# 1225/1225 [==============================] - 5s 4ms/step - loss: 0.9854 - accuracy: 0.5469 - val_loss: 1.0067 - val_accuracy: 0.5179
# Epoch 8/72
# 1225/1225 [==============================] - 5s 4ms/step - loss: 0.9870 - accuracy: 0.5437 - val_loss: 1.0072 - val_accuracy: 0.5179
# Epoch 9/72
# 1225/1225 [==============================] - 4s 4ms/step - loss: 0.9762 - accuracy: 0.5437 - val_loss: 1.0081 - val_accuracy: 0.5179
# Epoch 10/72
# 1225/1225 [==============================] - 4s 4ms/step - loss: 0.9734 - accuracy: 0.5429 - val_loss: 1.0040 - val_accuracy: 0.5179
# Epoch 11/72
# 1225/1225 [==============================] - 5s 4ms/step - loss: 0.9765 - accuracy: 0.5322 - val_loss: 0.9993 - val_accuracy: 0.5179
# Epoch 12/72
# 1225/1225 [==============================] - 5s 4ms/step - loss: 0.9645 - accuracy: 0.5478 - val_loss: 0.9941 - val_accuracy: 0.5179
# Epoch 13/72
# 1225/1225 [==============================] - 5s 4ms/step - loss: 0.9637 - accuracy: 0.5478 - val_loss: 0.9905 - val_accuracy: 0.5179
# Epoch 14/72
# 1225/1225 [==============================] - 5s 4ms/step - loss: 0.9622 - accuracy: 0.5461 - val_loss: 0.9859 - val_accuracy: 0.5179
# Epoch 15/72
# 1225/1225 [==============================] - 5s 4ms/step - loss: 0.9515 - accuracy: 0.5551 - val_loss: 0.9805 - val_accuracy: 0.5179
# Epoch 16/72
# 1225/1225 [==============================] - 5s 4ms/step - loss: 0.9380 - accuracy: 0.5600 - val_loss: 0.9732 - val_accuracy: 0.5179
# Epoch 17/72
# 1225/1225 [==============================] - 5s 4ms/step - loss: 0.9252 - accuracy: 0.5592 - val_loss: 0.9622 - val_accuracy: 0.5212
# Epoch 18/72
# 1225/1225 [==============================] - 4s 4ms/step - loss: 0.9213 - accuracy: 0.5649 - val_loss: 0.9453 - val_accuracy: 0.5244
# Epoch 19/72
# 1225/1225 [==============================] - 5s 4ms/step - loss: 0.9099 - accuracy: 0.5633 - val_loss: 0.9264 - val_accuracy: 0.5440
# Epoch 20/72
# 1225/1225 [==============================] - 5s 4ms/step - loss: 0.9222 - accuracy: 0.5592 - val_loss: 0.9172 - val_accuracy: 0.5798
# Epoch 21/72
# 1225/1225 [==============================] - 5s 4ms/step - loss: 0.9114 - accuracy: 0.5649 - val_loss: 0.9007 - val_accuracy: 0.5700
# Epoch 22/72
# 1225/1225 [==============================] - 4s 4ms/step - loss: 0.8850 - accuracy: 0.5894 - val_loss: 0.8976 - val_accuracy: 0.6352
# Epoch 23/72
# 1225/1225 [==============================] - 4s 4ms/step - loss: 0.8680 - accuracy: 0.6033 - val_loss: 0.8743 - val_accuracy: 0.5863
# Epoch 24/72
# 1225/1225 [==============================] - 4s 4ms/step - loss: 0.8672 - accuracy: 0.5910 - val_loss: 0.8671 - val_accuracy: 0.6450
# Epoch 25/72
# 1225/1225 [==============================] - 5s 4ms/step - loss: 0.8592 - accuracy: 0.6033 - val_loss: 0.8564 - val_accuracy: 0.6645
# Epoch 26/72
# 1225/1225 [==============================] - 6s 5ms/step - loss: 0.8561 - accuracy: 0.6008 - val_loss: 0.8471 - val_accuracy: 0.6352
# Epoch 27/72
# 1225/1225 [==============================] - 5s 4ms/step - loss: 0.8534 - accuracy: 0.5951 - val_loss: 0.8385 - val_accuracy: 0.6612
# Epoch 28/72
# 1225/1225 [==============================] - 5s 4ms/step - loss: 0.8272 - accuracy: 0.6261 - val_loss: 0.8313 - val_accuracy: 0.6906
# Epoch 29/72
# 1225/1225 [==============================] - 4s 4ms/step - loss: 0.8287 - accuracy: 0.6400 - val_loss: 0.8148 - val_accuracy: 0.6678
# Epoch 30/72
# 1225/1225 [==============================] - 4s 4ms/step - loss: 0.8067 - accuracy: 0.6408 - val_loss: 0.8100 - val_accuracy: 0.7134
# Epoch 31/72
# 1225/1225 [==============================] - 4s 4ms/step - loss: 0.8169 - accuracy: 0.6359 - val_loss: 0.7922 - val_accuracy: 0.6808
# Epoch 32/72
# 1225/1225 [==============================] - 4s 4ms/step - loss: 0.8354 - accuracy: 0.6384 - val_loss: 0.8015 - val_accuracy: 0.7101
# Epoch 33/72
# 1225/1225 [==============================] - 4s 4ms/step - loss: 0.8149 - accuracy: 0.6351 - val_loss: 0.7917 - val_accuracy: 0.6840
# Epoch 34/72
# 1225/1225 [==============================] - 4s 4ms/step - loss: 0.8002 - accuracy: 0.6473 - val_loss: 0.7981 - val_accuracy: 0.7134
# Epoch 35/72
# 1225/1225 [==============================] - 5s 4ms/step - loss: 0.7996 - accuracy: 0.6571 - val_loss: 0.7791 - val_accuracy: 0.7101
# Epoch 36/72
# 1225/1225 [==============================] - 5s 4ms/step - loss: 0.7985 - accuracy: 0.6441 - val_loss: 0.7796 - val_accuracy: 0.7003
# Epoch 37/72
# 1225/1225 [==============================] - 4s 4ms/step - loss: 0.7847 - accuracy: 0.6490 - val_loss: 0.7680 - val_accuracy: 0.7036
# Epoch 38/72
# 1225/1225 [==============================] - 4s 4ms/step - loss: 0.7911 - accuracy: 0.6441 - val_loss: 0.7586 - val_accuracy: 0.7329
# Epoch 39/72
# 1225/1225 [==============================] - 4s 4ms/step - loss: 0.7779 - accuracy: 0.6531 - val_loss: 0.7415 - val_accuracy: 0.7492
# Epoch 40/72
# 1225/1225 [==============================] - 4s 4ms/step - loss: 0.7967 - accuracy: 0.6580 - val_loss: 0.7734 - val_accuracy: 0.6808
# Epoch 41/72
# 1225/1225 [==============================] - 4s 4ms/step - loss: 0.7661 - accuracy: 0.6718 - val_loss: 0.7663 - val_accuracy: 0.7166
# Epoch 42/72
# 1225/1225 [==============================] - 5s 4ms/step - loss: 0.7801 - accuracy: 0.6718 - val_loss: 0.7377 - val_accuracy: 0.7134
# Epoch 43/72
# 1225/1225 [==============================] - 5s 4ms/step - loss: 0.7836 - accuracy: 0.6522 - val_loss: 0.7881 - val_accuracy: 0.6352
# Epoch 44/72
# 1225/1225 [==============================] - 5s 4ms/step - loss: 0.7758 - accuracy: 0.6629 - val_loss: 0.7287 - val_accuracy: 0.7329
# Epoch 45/72
# 1225/1225 [==============================] - 5s 4ms/step - loss: 0.7697 - accuracy: 0.6531 - val_loss: 0.7913 - val_accuracy: 0.6026
# Epoch 46/72
# 1225/1225 [==============================] - 5s 4ms/step - loss: 0.7617 - accuracy: 0.6776 - val_loss: 0.7247 - val_accuracy: 0.7557
# Epoch 47/72
# 1225/1225 [==============================] - 5s 4ms/step - loss: 0.7517 - accuracy: 0.6702 - val_loss: 0.7904 - val_accuracy: 0.5993
# Epoch 48/72
# 1225/1225 [==============================] - 5s 4ms/step - loss: 0.7716 - accuracy: 0.6588 - val_loss: 0.7126 - val_accuracy: 0.7492
# Epoch 49/72
# 1225/1225 [==============================] - 5s 4ms/step - loss: 0.7362 - accuracy: 0.6890 - val_loss: 0.7441 - val_accuracy: 0.6906
# Epoch 50/72

# %%
df_test_ = pd.read_csv(path_test)
df_test = df_test_.copy()
df_test['filename'] = df_test['filename'].map(lambda x: 'data/data/%04d.wav' % x)
print(len(df_test.index))
df_test.head(2)

# %%
features = []
for k,row in df_test.iterrows():
    data = extract_features(row['filename'])
    features.append([data])
df_features_test = pd.DataFrame(features, columns=['feature'])
print('Finished feature extraction from ', len(df_features_test), ' files')
# Out:
# Finished feature extraction from  1551  files

# %%
X_test = np.array(df_features_test.feature.tolist())
X_test = X_test.reshape(X_test.shape[0], num_rows, num_columns, num_channels)

# %%
y_prob = model.predict(X_test)
y_classes = y_prob.argmax(axis=-1)

# %%
len(X_test)
# Out:
# 1551

# %%
y_classes
# Out:
# array([1, 2, 1, ..., 1, 1, 0])

# %%
df_test_['label'] = y_classes

# %%
df_test_.to_csv('data/res.csv', index=None, header=None)
